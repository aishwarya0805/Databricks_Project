# %%
#import dataset from Kaggle
import kagglehub

path = kagglehub.dataset_download("carogonzalezgaltier/medical-appointment-scheduling-system")

print("Path to dataset files:", path)

# %%
#install kaggle library
# %pip install kagglehub

# %%
# %restart_python

# %%
#Display table names from imported dataset
import os

data_path = "/home/spark-9c17f399-96e7-499b-a777-e0/.cache/kagglehub/datasets/carogonzalezgaltier/medical-appointment-scheduling-system/versions/1"
os.listdir(data_path)

# %%
#loading dataset to pandas dataframe
import pandas as pd

df_appoint = pd.read_csv(f"{data_path}/appointments.csv")
df_appoint.head()

df_patient = pd.read_csv(f"{data_path}/patients.csv")
df_patient.head()

df_slot = pd.read_csv(f"{data_path}/slots.csv")
df_slot.head()

# %%
# %sql
ALTER TABLE appointments RENAME TO appointments_raw;
ALTER TABLE patients RENAME TO patients_raw;
ALTER TABLE slots RENAME TO slots_raw;
